# %%
import pandas

# %%
dtxt = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.txt")

# %%
dtxt
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dtxt2 = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees2.txt", delimiter = '|')

# %%
dtxt2
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9      Test     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.csv")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.csv", header = None)
dcsv
# Out:
#      0          1         2           3           4                    5  \
# 0   ID  FirstName  LastName  Department       Phone              Address
# 1    1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2    2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3    3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4    4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5    5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6    6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7    7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8    8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9    9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10  10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#          6                7
# 0   Salary           Skills
# 1    52000     Online Sales
# ...

# %%
dcsv = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.csv", header = None, names = ['A','B','C','D','E','F','G', 'H'])
dcsv
# Out:
#      A          B         C           D           E                    F  \
# 0   ID  FirstName  LastName  Department       Phone              Address
# 1    1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2    2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3    3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4    4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5    5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6    6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7    7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8    8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9    9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10  10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#          G                H
# 0   Salary           Skills
# 1    52000     Online Sales
# ...

# %%
dcsv = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.csv", header = None, prefix = 'COL')
dcsv
# Out:
#    COL0       COL1      COL2        COL3        COL4                 COL5  \
# 0    ID  FirstName  LastName  Department       Phone              Address
# 1     1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2     2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3     3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4     4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5     5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6     6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7     7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8     8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9     9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10   10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#       COL6             COL7
# 0   Salary           Skills
# ...

# %%
dcsv = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.csv")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.set_index("ID")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.set_index("ID", inplace = True)
dcsv
# Out:
#    FirstName  LastName Department       Phone              Address  Salary  \
# ID
# 1       Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 2       Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 3        Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 4       John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 5      Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 6       Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 7    Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 8     Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 9        Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#              Skills
# ID
# 1      Online Sales
# 2        Networking
# 3      Python, Java
# 4      Facebook Ads
# 5     Instagram Ads
# ...

# %%
dcsv.set_index('Address', inplace = True)

# %%
dcsv
# Out:
#                     FirstName  LastName Department       Phone  Salary  \
# Address
# 1st Address, Miami       Luke   Phillip      Sales  1234567890   52000
# 2nd Address, Miami       Jack    Darren         IT  1234567891   52200
# 3rd Address, Miami        Ken      Wood         IT  1234567892   58000
# 4th Address, Miami       John    Wilson  Marketing  1234567893   58700
# 5th Address, Miami      Emily    Larson  Marketing  1234567894   60000
# 6th Address, Miami       Anna  Sullivan      Sales  1234567895   54000
# 7th Address, Miami    Richard     Smith  Logistics  1234567896   56000
# 8th Address, Miami     Ronnie     Moore      Sales  1234567897   49000
# 9th Address, Miami        Ron     Drake         IT  1234567898   53000
# 10th Address, Miami     Wayne    Barker  Logistics  1234567899   59500
#
#                               Skills
# Address
# 1st Address, Miami      Online Sales
# 2nd Address, Miami        Networking
# 3rd Address, Miami      Python, Java
# ...

# %%
dcsv = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.csv")
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.shape
# Out:
# (10, 8)

# %%
dcsv = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.csv", skiprows = 4)
dcsv
# Out:
#     4     John    Wilson  Marketing  1234567893   4th Address, Miami  58700  \
# 0   5    Emily    Larson  Marketing  1234567894   5th Address, Miami  60000
# 1   6     Anna  Sullivan      Sales  1234567895   6th Address, Miami  54000
# 2   7  Richard     Smith  Logistics  1234567896   7th Address, Miami  56000
# 3   8   Ronnie     Moore      Sales  1234567897   8th Address, Miami  49000
# 4   9      Ron     Drake         IT  1234567898   9th Address, Miami  53000
# 5  10    Wayne    Barker  Logistics  1234567899  10th Address, Miami  59500
#
#       Facebook Ads
# 0    Instagram Ads
# 1  In-Person Sales
# 2  Warehouse Mgmt.
# 3     Online Sales
# 4    Linux Servers
# 5  Product Loading

# %%
dcsv = pandas.read_csv("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.csv", nrows = 5)
dcsv
# Out:
#    ID FirstName LastName Department       Phone             Address  Salary  \
# 0   1      Luke  Phillip      Sales  1234567890  1st Address, Miami   52000
# 1   2      Jack   Darren         IT  1234567891  2nd Address, Miami   52200
# 2   3       Ken     Wood         IT  1234567892  3rd Address, Miami   58000
# 3   4      John   Wilson  Marketing  1234567893  4th Address, Miami   58700
# 4   5     Emily   Larson  Marketing  1234567894  5th Address, Miami   60000
#
#           Skills
# 0   Online Sales
# 1     Networking
# 2   Python, Java
# 3   Facebook Ads
# 4  Instagram Ads

# %%
djson = pandas.read_json("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.json")
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dxlsx = pandas.read_excel("/Users/hrobbin/projects/python/data_analysis/srcs/Employees.xlsx")
dxlsx
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
url = 'https://en.wikipedia.org/wiki/Python_(programming_language)'

# %%
d = pandas.read_html(url)
d
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1261         """Send a complete request to the server."""
# -> 1262         self._send_request(method, url, body, headers, encode_chunked)
#    1263
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
url = 'https://en.wikipedia.org/wiki/Python_(programming_language)'
d = pandas.read_html(url)
d
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1261         """Send a complete request to the server."""
# -> 1262         self._send_request(method, url, body, headers, encode_chunked)
#    1263
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
import ssl 

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

# %%
url = 'https://en.wikipedia.org/wiki/Python_(programming_language)'
d = pandas.read_html(url)
d
# Out:
# [                                                    0  \
#  0                                                 NaN
#  1                                            Paradigm
#  2                                         Designed by
#  3                                           Developer
#  4                                      First appeared
#  5                                                 NaN
#  6                                      Stable release
#  7                                   Typing discipline
#  8                                                  OS
#  9                                             License
#  10                                Filename extensions
#  11                                            Website
#  12                              Major implementations
#  13  CPython, PyPy, Stackless Python, MicroPython, ...
#  14                                           Dialects
#  15                       Cython, RPython, Starlark[9]
# ...

# %%
d[2]
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vtePython  \
# 0                                    Implementations
# ...

# %%
d = pandas.read_html(url)[1]

# %%
d
# Out:
#                    Type Mutability  \
# 0                  bool  immutable
# 1             bytearray    mutable
# 2                 bytes  immutable
# 3               complex  immutable
# 4                  dict    mutable
# 5             ellipsisa  immutable
# 6                 float  immutable
# 7             frozenset  immutable
# 8                   int  immutable
# 9                  list    mutable
# 10            NoneTypea  immutable
# 11  NotImplementedTypea  immutable
# 12                range  immutable
# 13                  set    mutable
# 14                  str  immutable
# 15                tuple  immutable
#
#                                           Description  \
# 0                                       Boolean value
# 1                                   Sequence of bytes
# 2                                   Sequence of bytes
# 3        Complex number with real and imaginary parts
# 4   Associative array (or dictionary) of key and v...
# ...
