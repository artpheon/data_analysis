# %%
import pandas
djson = pandas.read_json('/home/hrobbin/python/python_data_analysis/srcs/Employees.json')
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
djson['Badge ID'] = ['00', '01', '02', '03', '04', '05', '06', '07', '08', '09']

# %%
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills Badge ID
# 0     Online Sales       00
# 1       Networking       01
# ...

# %%
djson['Badge ID'] = djson['FirstName'] + '2021'

# %%
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills     Badge ID
# 0     Online Sales     Luke2021
# 1       Networking     Jack2021
# ...

# %%
djson['FirstName'] = 'Jack'

# %%
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Jack   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3      Jack      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      Jack    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5      Jack    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Jack  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7      Jack     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8      Jack     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9      Jack     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10      Jack    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills     Badge ID
# 0     Online Sales     Luke2021
# 1       Networking     Jack2021
# ...

# %%
djson.shape
# Out:
# (10, 9)

# %%
djson.shape[0]
# Out:
# 10

# %%
djson.loc[djson['Department'] == 'IT', 'Salary'] = '90909'

# %%
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address Salary  \
# 0   1      Jack   Phillip      Sales  1234567890   1st Address, Miami  52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami  90909
# 2   3      Jack      Wood         IT  1234567892   3rd Address, Miami  90909
# 3   4      Jack    Wilson  Marketing  1234567893   4th Address, Miami  58700
# 4   5      Jack    Larson  Marketing  1234567894   5th Address, Miami  60000
# 5   6      Jack  Sullivan      Sales  1234567895   6th Address, Miami  54000
# 6   7      Jack     Smith  Logistics  1234567896   7th Address, Miami  56000
# 7   8      Jack     Moore      Sales  1234567897   8th Address, Miami  49000
# 8   9      Jack     Drake         IT  1234567898   9th Address, Miami  90909
# 9  10      Jack    Barker  Logistics  1234567899  10th Address, Miami  59500
#
#             Skills     Badge ID
# 0     Online Sales     Luke2021
# 1       Networking     Jack2021
# ...

# %%
djson['FirstName'] = djson.shape[0] * ['John']

# %%
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address Salary  \
# 0   1      John   Phillip      Sales  1234567890   1st Address, Miami  52000
# 1   2      John    Darren         IT  1234567891   2nd Address, Miami  90909
# 2   3      John      Wood         IT  1234567892   3rd Address, Miami  90909
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami  58700
# 4   5      John    Larson  Marketing  1234567894   5th Address, Miami  60000
# 5   6      John  Sullivan      Sales  1234567895   6th Address, Miami  54000
# 6   7      John     Smith  Logistics  1234567896   7th Address, Miami  56000
# 7   8      John     Moore      Sales  1234567897   8th Address, Miami  49000
# 8   9      John     Drake         IT  1234567898   9th Address, Miami  90909
# 9  10      John    Barker  Logistics  1234567899  10th Address, Miami  59500
#
#             Skills     Badge ID
# 0     Online Sales     Luke2021
# 1       Networking     Jack2021
# ...

# %%
djson.loc[djson['ID'] == 9, ['Salary', 'Phone']] = ['55000', '88005553535']

# %%
djson
# Out:
#    ID FirstName  LastName Department        Phone              Address Salary  \
# 0   1      John   Phillip      Sales   1234567890   1st Address, Miami  52000
# 1   2      John    Darren         IT   1234567891   2nd Address, Miami  90909
# 2   3      John      Wood         IT   1234567892   3rd Address, Miami  90909
# 3   4      John    Wilson  Marketing   1234567893   4th Address, Miami  58700
# 4   5      John    Larson  Marketing   1234567894   5th Address, Miami  60000
# 5   6      John  Sullivan      Sales   1234567895   6th Address, Miami  54000
# 6   7      John     Smith  Logistics   1234567896   7th Address, Miami  56000
# 7   8      John     Moore      Sales   1234567897   8th Address, Miami  49000
# 8   9      John     Drake         IT  88005553535   9th Address, Miami  55000
# 9  10      John    Barker  Logistics   1234567899  10th Address, Miami  59500
#
#             Skills     Badge ID
# 0     Online Sales     Luke2021
# 1       Networking     Jack2021
# ...

# %%
djson
# Out:
#    ID FirstName  LastName Department        Phone              Address Salary  \
# 0   1      John   Phillip      Sales   1234567890   1st Address, Miami  52000
# 1   2      John    Darren         IT   1234567891   2nd Address, Miami  90909
# 2   3      John      Wood         IT   1234567892   3rd Address, Miami  90909
# 3   4      John    Wilson  Marketing   1234567893   4th Address, Miami  58700
# 4   5      John    Larson  Marketing   1234567894   5th Address, Miami  60000
# 5   6      John  Sullivan      Sales   1234567895   6th Address, Miami  54000
# 6   7      John     Smith  Logistics   1234567896   7th Address, Miami  56000
# 7   8      John     Moore      Sales   1234567897   8th Address, Miami  49000
# 8   9      John     Drake         IT  88005553535   9th Address, Miami  55000
# 9  10      John    Barker  Logistics   1234567899  10th Address, Miami  59500
#
#             Skills     Badge ID
# 0     Online Sales     Luke2021
# 1       Networking     Jack2021
# ...

# %%
djson.drop('LastName', 'columns')
# Out:
# /tmp/ipykernel_31430/3689425552.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   djson.drop('LastName', 'columns')
#    ID FirstName Department        Phone              Address Salary  \
# 0   1      John      Sales   1234567890   1st Address, Miami  52000
# 1   2      John         IT   1234567891   2nd Address, Miami  90909
# 2   3      John         IT   1234567892   3rd Address, Miami  90909
# 3   4      John  Marketing   1234567893   4th Address, Miami  58700
# 4   5      John  Marketing   1234567894   5th Address, Miami  60000
# 5   6      John      Sales   1234567895   6th Address, Miami  54000
# 6   7      John  Logistics   1234567896   7th Address, Miami  56000
# 7   8      John      Sales   1234567897   8th Address, Miami  49000
# 8   9      John         IT  88005553535   9th Address, Miami  55000
# 9  10      John  Logistics   1234567899  10th Address, Miami  59500
#
# ...

# %%
djson.drop('LastName', 'columns', inplace = True)
# Out:
# /tmp/ipykernel_31430/2587438616.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   djson.drop('LastName', 'columns', inplace = True)

# %%
djson
# Out:
#    ID FirstName Department        Phone              Address Salary  \
# 0   1      John      Sales   1234567890   1st Address, Miami  52000
# 1   2      John         IT   1234567891   2nd Address, Miami  90909
# 2   3      John         IT   1234567892   3rd Address, Miami  90909
# 3   4      John  Marketing   1234567893   4th Address, Miami  58700
# 4   5      John  Marketing   1234567894   5th Address, Miami  60000
# 5   6      John      Sales   1234567895   6th Address, Miami  54000
# 6   7      John  Logistics   1234567896   7th Address, Miami  56000
# 7   8      John      Sales   1234567897   8th Address, Miami  49000
# 8   9      John         IT  88005553535   9th Address, Miami  55000
# 9  10      John  Logistics   1234567899  10th Address, Miami  59500
#
#             Skills     Badge ID
# 0     Online Sales     Luke2021
# 1       Networking     Jack2021
# 2     Python, Java      Ken2021
# 3     Facebook Ads     John2021
# 4    Instagram Ads    Emily2021
# ...

# %%
djson.drop(djson.index[4:8])
# Out:
#    ID FirstName Department        Phone              Address Salary  \
# 0   1      John      Sales   1234567890   1st Address, Miami  52000
# 1   2      John         IT   1234567891   2nd Address, Miami  90909
# 2   3      John         IT   1234567892   3rd Address, Miami  90909
# 3   4      John  Marketing   1234567893   4th Address, Miami  58700
# 8   9      John         IT  88005553535   9th Address, Miami  55000
# 9  10      John  Logistics   1234567899  10th Address, Miami  59500
#
#             Skills   Badge ID
# 0     Online Sales   Luke2021
# 1       Networking   Jack2021
# 2     Python, Java    Ken2021
# 3     Facebook Ads   John2021
# 8    Linux Servers    Ron2021
# 9  Product Loading  Wayne2021

# %%
djson
# Out:
#    ID FirstName Department        Phone              Address Salary  \
# 0   1      John      Sales   1234567890   1st Address, Miami  52000
# 1   2      John         IT   1234567891   2nd Address, Miami  90909
# 2   3      John         IT   1234567892   3rd Address, Miami  90909
# 3   4      John  Marketing   1234567893   4th Address, Miami  58700
# 4   5      John  Marketing   1234567894   5th Address, Miami  60000
# 5   6      John      Sales   1234567895   6th Address, Miami  54000
# 6   7      John  Logistics   1234567896   7th Address, Miami  56000
# 7   8      John      Sales   1234567897   8th Address, Miami  49000
# 8   9      John         IT  88005553535   9th Address, Miami  55000
# 9  10      John  Logistics   1234567899  10th Address, Miami  59500
#
#             Skills     Badge ID
# 0     Online Sales     Luke2021
# 1       Networking     Jack2021
# 2     Python, Java      Ken2021
# 3     Facebook Ads     John2021
# 4    Instagram Ads    Emily2021
# ...

# %%
djson.drop(djson.columns[1:5], 1)
# Out:
# /tmp/ipykernel_31430/3371670393.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   djson.drop(djson.columns[1:5], 1)
#    ID Salary           Skills     Badge ID
# 0   1  52000     Online Sales     Luke2021
# 1   2  90909       Networking     Jack2021
# 2   3  90909     Python, Java      Ken2021
# 3   4  58700     Facebook Ads     John2021
# 4   5  60000    Instagram Ads    Emily2021
# 5   6  54000  In-Person Sales     Anna2021
# 6   7  56000  Warehouse Mgmt.  Richard2021
# 7   8  49000     Online Sales   Ronnie2021
# 8   9  55000    Linux Servers      Ron2021
# 9  10  59500  Product Loading    Wayne2021
